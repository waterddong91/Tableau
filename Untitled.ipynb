# %%
import pandas as pd

# %%
csv_1 = "Resources/JC-202001-citibike-tripdata.csv"
csv_2 = "Resources/JC-202002-citibike-tripdata.csv"
csv_3 = "Resources/JC-202003-citibike-tripdata.csv"
csv_4 = "Resources/JC-202004-citibike-tripdata.csv"
csv_5 = "Resources/JC-202005-citibike-tripdata.csv"
csv_6 = "Resources/JC-202006-citibike-tripdata.csv"
csv_7 = "Resources/JC-202007-citibike-tripdata.csv"
csv_8 = "Resources/JC-202008-citibike-tripdata.csv"
csv_9 = "Resources/JC-202009-citibike-tripdata.csv"
csv_10 = "Resources/JC-202010-citibike-tripdata.csv"
csv_11 = "Resources/JC-202011-citibike-tripdata.csv"
csv_12 = "Resources/JC-202012-citibike-tripdata.csv"
csv_21_01 = "Resources/202101.csv"

# %%
bike_1 = pd.read_csv(csv_1)
bike_2 = pd.read_csv(csv_2)
bike_3 = pd.read_csv(csv_3)
bike_4 = pd.read_csv(csv_4)
bike_5 = pd.read_csv(csv_5)
bike_6 = pd.read_csv(csv_6)
bike_7 = pd.read_csv(csv_7)
bike_8 = pd.read_csv(csv_8)
bike_9 = pd.read_csv(csv_9)
bike_10 = pd.read_csv(csv_10)
bike_11 = pd.read_csv(csv_11)
bike_12 = pd.read_csv(csv_12)
bike_2021 = pd.read_csv(csv_21_01)

# %%
bike_1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
bike_df = pd.concat([bike_1, bike_2, bike_3, bike_4, bike_5, bike_6, bike_7, bike_8, bike_9, bike_10, bike_11, bike_12, bike_2021])

# %%
bike_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
bike_df.to_csv("bike_df.csv")
